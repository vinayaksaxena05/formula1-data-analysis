# %%
import fastf1
import matplotlib.pyplot as plt
from pathlib import Path

fastf1.Cache.enable_cache("../cache")

# %%
schedule = fastf1.get_event_schedule(2025)
races = schedule[schedule['EventName'] != 'Pre-Season Testing']

for _, row in races.iterrows():

    race_name = row['EventName'].replace(" Grand Prix", "")
    folder_name = race_name.lower().replace(" ", "_")

    race_folder = Path(f"../data/raw/2025/{folder_name}/telemetry")
    race_folder.mkdir(parents=True, exist_ok=True)

    session = fastf1.get_session(2025, row['RoundNumber'], 'R')
    session.load()

    for driver in session.drivers:

        driver_name = session.get_driver(driver)['Abbreviation']

        telemetry = (
            session.laps
            .pick_drivers(driver)
            .get_telemetry()
        )

        telemetry.to_csv(
            race_folder / f"{driver_name}.csv",
            index=False
        )
# Out:
#     RoundNumber               Country           Location  \
# 0             0               Bahrain             Sakhir
# 1             1             Australia          Melbourne
# 2             2                 China           Shanghai
# 3             3                 Japan             Suzuka
# 4             4               Bahrain             Sakhir
# 5             5          Saudi Arabia             Jeddah
# 6             6         United States      Miami Gardens
# 7             7                 Italy              Imola
# 8             8                Monaco             Monaco
# 9             9                 Spain          Barcelona
# 10           10                Canada           Montréal
# 11           11               Austria          Spielberg
# 12           12        United Kingdom        Silverstone
# 13           13               Belgium  Spa-Francorchamps
# 14           14               Hungary           Budapest
# ...
